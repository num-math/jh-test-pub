# %% [markdown]
# # Week 1: Introduction
#
# [![Run in JupyterHub](https://img.shields.io/badge/Run%20in-JupyterHub-F37626?logo=jupyter)](https://jupyterhub.example.com/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgitlab.example.com%2Fgroup%2Fpublic-notebooks.git&branch=main&subpath=notebooks%2Fweek-01-intro.ipynb)
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/num-math/jh-test-pub/blob/main/notebooks/week-01-intro.ipynb)
#
# A simple sanity check that Python is working.

# %%
import sys

print(f"Python {sys.version}")

# %%
print("Hello, world!")

# %% [markdown]
# And we are good to go.
