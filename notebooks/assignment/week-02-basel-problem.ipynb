# %% [markdown]
# # Week 2: Basel problem
#
# **Assignment:** [![Run in JupyterHub](https://img.shields.io/badge/Run%20in-JupyterHub-F37626?logo=jupyter)](https://hpc.troja.mff.cuni.cz:8000/hub/user-redirect/git-pull?app=lab&repo=https%3A%2F%2Fgitlab.karlin.mff.cuni.cz%2Fznm%2Ftest-jh-student&branch=main&subpath=notebooks%2Fassignment%2Fweek-02-basel-problem.ipynb) [![Download .ipynb](https://img.shields.io/badge/Download-.ipynb-blue)](https://gitlab.karlin.mff.cuni.cz/znm/test-jh-student/-/raw/main/notebooks/assignment/week-02-basel-problem.ipynb?inline=false) [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/num-math/jh-test-pub/blob/main/notebooks/assignment/week-02-basel-problem.ipynb)
#
# **Solution:** [![Run in JupyterHub](https://img.shields.io/badge/Run%20in-JupyterHub-F37626?logo=jupyter)](https://hpc.troja.mff.cuni.cz:8000/hub/user-redirect/git-pull?app=lab&repo=https%3A%2F%2Fgitlab.karlin.mff.cuni.cz%2Fznm%2Ftest-jh-student&branch=main&subpath=notebooks%2Fsolution%2Fweek-02-basel-problem.ipynb) [![Download .ipynb](https://img.shields.io/badge/Download-.ipynb-blue)](https://gitlab.karlin.mff.cuni.cz/znm/test-jh-student/-/raw/main/notebooks/solution/week-02-basel-problem.ipynb?inline=false) [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/num-math/jh-test-pub/blob/main/notebooks/solution/week-02-basel-problem.ipynb)
#
# This notebook starts from the naive series
#
# $$
# \sum_{n=1}^{\infty} \frac{1}{n^2}
# $$
#
# and compares its partial sums against the exact value $\pi^2 / 6$.

# %%
from math import pi

terms = 200
partial_sums = []
total = 0.0

# %% [markdown]
# :::{admonition} Task
# Fill in the following code block:
# :::

# %%
for n in range(1, terms + 1):
    total += ...
    partial_sums.append(total)

# %%
target = pi**2 / 6.0

print(f"S_{terms} = {partial_sums[-1]:.12f}")
print(f"pi^2 / 6 = {target:.12f}")
print(f"error    = {target - partial_sums[-1]:.12e}")

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(range(1, terms + 1), partial_sums, label=r"$\sum_{n=1}^{N} 1/n^2$")
ax.axhline(target, color="black", linestyle="--", label=r"$\pi^2 / 6$")
ax.set_xlabel("N")
ax.set_ylabel("partial sum")
ax.set_title("Naive convergence of the Basel problem")
ax.legend()
plt.show()

# %% [markdown]
# The convergence is slow but visible even for a very small, intentionally simple example.
